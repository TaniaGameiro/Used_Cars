# %% [markdown]
# # Used Cars - Data Wrangling

# %% [markdown]
# We would like to build an app to search for used cars in the area, based on the price, year,
# mileage, make and model. We will be working with the Kaggle dataset, that was acquired by
# TrueCar.com for used car listings on 9/24/2017.
#
# We will begin by importing all of the required libraries.

# %%
import numpy as np
import os
import pandas as pd
import sys
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')
import seaborn as sns
sns.set(color_codes=True)

# %% [markdown]
# We are importing the CSV we retreived from Kaggle and saved on our desktop.

# %%
UsedCars = pd.read_csv("/Users/Nora/Desktop/true_car_listings.csv")

# %% [markdown]
# Taking a quick look at the datset to see if there are improvements or even just to see what the data looks like.

# %%
UsedCars.head()
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon    UT  19UDE2F32GA001284  Acura
#
#           Model
# 0    ILX6-Speed
# 1    ILX5-Speed
# 2    ILX6-Speed
# 3    ILX5-Speed
# 4  ILXAutomatic

# %%
UsedCars.dtypes
# Out:
# Price       int64
# Year        int64
# Mileage     int64
# City       object
# State      object
# Vin        object
# Make       object
# Model      object
# dtype: object

# %% [markdown]
# We will verify if there are any NA's in the dataset just to be sure.

# %%
UsedCars.isnull().sum(axis=0)
# Out:
# Price      0
# Year       0
# Mileage    0
# City       0
# State      0
# Vin        0
# Make       0
# Model      0
# dtype: int64

# %%
UsedCars.corr()
# Out:
#             Price      Year   Mileage
# Price    1.000000  0.401250 -0.421237
# Year     0.401250  1.000000 -0.764849
# Mileage -0.421237 -0.764849  1.000000

# %%
UsedCars.describe()
# Out:
#                Price           Year       Mileage
# count  852122.000000  852122.000000  8.521220e+05
# mean    21464.100210    2013.289145  5.250779e+04
# std     13596.202241       3.414987  4.198896e+04
# min      1500.000000    1997.000000  5.000000e+00
# 25%     13000.000000    2012.000000  2.383600e+04
# 50%     18500.000000    2014.000000  4.025600e+04
# 75%     26995.000000    2016.000000  7.218600e+04
# max    499500.000000    2018.000000  2.856196e+06

# %%
UsedCars.sample(20)
# Out:
#         Price  Year  Mileage           City State                Vin  \
# 169201  20991  2011   125062        Houston    TX  3GCPKSE38BG269501
# 482571  15999  2016    42349     Fort Wayne    IN  1C4NJDBB3GD521791
# 269476  18999  2015    10724      Escondido    CA  1FATP8EM6F5330150
# 356226  23687  2015    20138      Escondido    CA  1GTH5BEA5F1210114
# 724222   8750  2006   104036      Anchorage    AK  JF4GG616X6G051367
# 420044  26103  2014    37902  Thousand Oaks    CA  5FNRL5H63EB030185
# 307867  22300  2012    89637   Wilkes-Barre    PA  1FTFW1ET1CKD17750
# 512012  27990  2016    24985       Florence    SC  1C4RJEAGXGC481039
# 779478  14995  2014    41910      Glassboro    NJ  2T1BURHE1EC133610
# 718461  18997  2013    90750       McKinney    TX  1C6RR6KT9DS724469
# 253587  10786  2013    33944         Tucson    AZ  1FADP3F28DL363972
# 220293  19990  2013    49478   Saddle Brook    NJ  2C3CDYBT1DH500553
# 584757  10997  2012    39950       Temecula    CA  1YVHZ8DH8C5M27256
# 464701   5995  2006   136110       Pasadena    MD  KM8SC13D06U099324
# 624378  13990  2015    76262       Marietta    GA  WMWXP7C51F2C60060
# 56222   53999  2015     6982      Hollywood    FL  WBA6B2C55FD130068
# 99438    8997  2013    69450         Victor    NY  1G1PC5SB2D7325143
# 360714  29542  2015    39050     New Castle    DE  1GKKVRKD2FJ110036
# 383543  13975  2014    35732        Yonkers    NY  2HGFB2F89EH556289
# 637795  14500  2016    49605          Clive    IA  1N4AL3AP2GN326331
#
#              Make               Model
# 169201  Chevrolet           Silverado
# 482571       Jeep        CompassSport
# 269476       Ford  MustangConvertible
# 356226        GMC      CanyonExtended
# 724222       Saab             9-2X4dr
# 420044      Honda         OdysseyEX-L
# 307867       Ford            F-1504WD
# 512012       Jeep               Grand
# 779478     Toyota           CorollaLE
# 718461        Ram        1500Express,
# 253587       Ford          FocusSedan
# 220293      Dodge       ChallengerR/T
# 584757      Mazda           Mazda64dr
# 464701    Hyundai               Santa
# 624378       MINI              Cooper
# 56222         BMW                   6
# 99438   Chevrolet            Cruze1LT
# 360714        GMC           AcadiaAWD
# 383543      Honda               Civic
# 637795     Nissan           Altima2.5

# %% [markdown]
# Producing a quick statistical summary to see what the mean and standard deviation, as well as all of the other available measurements.

# %%
print("Table 1: Summary of Statistical Measurements")
UsedCars.describe(include='all').T
# Out:
# Table 1: Summary of Statistical Measurements
#           count  unique                top    freq     mean      std   min  \
# Price    852122     NaN                NaN     NaN  21464.1  13596.2  1500
# Year     852122     NaN                NaN     NaN  2013.29  3.41499  1997
# Mileage  852122     NaN                NaN     NaN  52507.8    41989     5
# City     852122    2553            Houston   12703      NaN      NaN   NaN
# State    852122      59                 TX   94654      NaN      NaN   NaN
# Vin      852122  852075  1FMCU0F75GUA44645       2      NaN      NaN   NaN
# Make     852122      58               Ford  110432      NaN      NaN   NaN
# Model    852122    2736          Silverado   24932      NaN      NaN   NaN
#
#            25%    50%    75%         max
# Price    13000  18500  26995      499500
# Year      2012   2014   2016        2018
# Mileage  23836  40256  72186  2.8562e+06
# City       NaN    NaN    NaN         NaN
# State      NaN    NaN    NaN         NaN
# Vin        NaN    NaN    NaN         NaN
# Make       NaN    NaN    NaN         NaN
# Model      NaN    NaN    NaN         NaN

# %% [markdown]
# We're creating a new column called "Transmission" to represent if the vehicle is automatic or manual transmission - when the information is available in the Model column.

# %%
UsedCars['Transmission'] = UsedCars.Model.str.extract('(Speed|Automatic)')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %%
UsedCars.head()
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon    UT  19UDE2F32GA001284  Acura
#
#           Model Transmission
# 0    ILX6-Speed        Speed
# 1    ILX5-Speed        Speed
# 2    ILX6-Speed        Speed
# 3    ILX5-Speed        Speed
# 4  ILXAutomatic    Automatic

# %% [markdown]
# We notice we creating the new column, but the Model column still includes the Speed and Automatic values. Let's clean that up.

# %%
UsedCars['Model'] = UsedCars['Model'].str.replace('-Speed', '')
UsedCars['Model'] = UsedCars['Model'].str.replace('-Automatic', '')
UsedCars['Model'] = UsedCars['Model'].str.replace('Speed', '')
UsedCars['Model'] = UsedCars['Model'].str.replace('Automatic', '')
UsedCars.head()
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon    UT  19UDE2F32GA001284  Acura
#
#   Model Transmission
# 0  ILX6        Speed
# 1  ILX5        Speed
# 2  ILX6        Speed
# 3  ILX5        Speed
# 4   ILX    Automatic

# %% [markdown]
# Since we created a new column, we will check again if there are any NA values.

# %%
UsedCars.isnull().sum(axis=0)
# Out:
# Price                0
# Year                 0
# Mileage              0
# City                 0
# State                0
# Vin                  0
# Make                 0
# Model                0
# Transmission    845369
# dtype: int64

# %% [markdown]
# When splitting the Model column and creating the Transmission column, it created multiple lines with NA values. Let's clean that up by filling the NAs with blank.

# %%
UsedCars.Transmission = UsedCars.Transmission.fillna('')

# %%
UsedCars.isnull().sum(axis=0)
# Out:
# Price           0
# Year            0
# Mileage         0
# City            0
# State           0
# Vin             0
# Make            0
# Model           0
# Transmission    0
# dtype: int64

# %% [markdown]
# We'll not save the cleaned file in order to start with our Exploratory Analysis.

# %%
UsedCars.to_csv('/Users/Nora/Desktop/true_car_listings.csv', index=False)
